# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="si5Q5va86D9QA05LgXR6")
project = rf.workspace("kjsce-mk9v5").project("player-and-speed-detection")
model=project.version(1).model
version = project.version(1)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-1.0.1-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 1.7 MB/s eta 0:00:00
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.22.4)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 5.4 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.26.15)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from roboflow) (6.0)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.0.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.9/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from roboflow) (8.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (4.39.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (23.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->roboflow) (2.0.12)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.15.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=f735f9e640ec5b3126b720c3b40bc3b7eb4fc605196cea2440dc50d3eb5bd137
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-0.10.1 roboflow-1.0.1 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset=project.version(1).download('yolov5')
# Out:
# Downloading Dataset Version Zip in player-and-speed-detection-1 to yolov5pytorch: 100% [15340702 / 15340702] bytes
# Extracting Dataset Version Zip to player-and-speed-detection-1 in yolov5pytorch:: 100%|██████████| 508/508 [00:00<00:00, 2228.12it/s]

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5 
# %cd yolov5
# !git reset --hard 064365d8683fd002e9ad789c1e91fa3d021b44f0
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15348, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15348 (delta 2), reused 6 (delta 0), pack-reused 15335
# Receiving objects: 100% (15348/15348), 14.16 MiB | 29.17 MiB/s, done.
# Resolving deltas: 100% (10526/10526), done.
# /content/yolov5
# HEAD is now at 064365d Update parse_opt() in export.py to work as in train.py (#10789)

# %%
# install dependencies
# !pip install -qr requirements.txt
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.6 MB/s eta 0:00:00
# Setup complete. Using torch 1.13.1+cu116 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# %cat {dataset.location}/data.yaml
# Out:
# cat: {dataset.location}/data.yaml: No such file or directory

# %%
# define number of classes based on YAML
import yaml
with open(dataset.location + "/data.yaml", 'r') as stream:
    num_classes = str(yaml.safe_load(stream)['nc'])

# %%
#model configuration
# %cat /content/yolov5/models/yolov5s.yaml
# Out:
# # YOLOv5 🚀 by Ultralytics, GPL-3.0 license
#
# # Parameters
# nc: 80  # number of classes
# depth_multiple: 0.33  # model depth multiple
# width_multiple: 0.50  # layer channel multiple
# anchors:
#   - [10,13, 16,30, 33,23]  # P3/8
#   - [30,61, 62,45, 59,119]  # P4/16
#   - [116,90, 156,198, 373,326]  # P5/32
#
# # YOLOv5 v6.0 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Conv, [64, 6, 2, 2]],  # 0-P1/2
#    [-1, 1, Conv, [128, 3, 2]],  # 1-P2/4
#    [-1, 3, C3, [128]],
#    [-1, 1, Conv, [256, 3, 2]],  # 3-P3/8
#    [-1, 6, C3, [256]],
#    [-1, 1, Conv, [512, 3, 2]],  # 5-P4/16
#    [-1, 9, C3, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],  # 7-P5/32
#    [-1, 3, C3, [1024]],
#    [-1, 1, SPPF, [1024, 5]],  # 9
#   ]
#
# # YOLOv5 v6.0 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],  # cat backbone P4
#    [-1, 3, C3, [512, False]],  # 13
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],  # cat backbone P3
#    [-1, 3, C3, [256, False]],  # 17 (P3/8-small)
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],  # cat head P4
#    [-1, 3, C3, [512, False]],  # 20 (P4/16-medium)
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],  # cat head P5
#    [-1, 3, C3, [1024, False]],  # 23 (P5/32-large)
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],  # Detect(P3, P4, P5)
#   ]

# %%
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
# %%writetemplate /content/yolov5/models/custom_yolov5s.yaml
#
# # parameters
# nc: {num_classes}
# depth_multiple: 0.33
# width_multiple: 0.50
#
# # anchors
# anchors:
#   - [10,13, 16,30, 33,23]
#   - [30,61, 62,45, 59,119]
#   - [116,90, 156,198, 373,326]
#
# # YOLOv5 backbone
# backbone:
#   # [from, number, module, args]
#   [[-1, 1, Focus, [64, 3]],
#    [-1, 1, Conv, [128, 3, 2]],
#    [-1, 3, BottleneckCSP, [128]],
#    [-1, 1, Conv, [256, 3, 2]],
#    [-1, 9, BottleneckCSP, [256]],
#    [-1, 1, Conv, [512, 3, 2]],
#    [-1, 9, BottleneckCSP, [512]],
#    [-1, 1, Conv, [1024, 3, 2]],
#    [-1, 1, SPP, [1024, [5, 9, 13]]],
#    [-1, 3, BottleneckCSP, [1024, False]],
#   ]
#
# # YOLOv5 head
# head:
#   [[-1, 1, Conv, [512, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 6], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [512, False]],
#
#    [-1, 1, Conv, [256, 1, 1]],
#    [-1, 1, nn.Upsample, [None, 2, 'nearest']],
#    [[-1, 4], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [256, False]],
#
#    [-1, 1, Conv, [256, 3, 2]],
#    [[-1, 14], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [512, False]],
#
#    [-1, 1, Conv, [512, 3, 2]],
#    [[-1, 10], 1, Concat, [1]],
#    [-1, 3, BottleneckCSP, [1024, False]],
#
#    [[17, 20, 23], 1, Detect, [nc, anchors]],
#   ]

# %%
# %%time
# %cd /content/yolov5/
# !python train.py --img 416 --batch 16 --epochs 100 --data {dataset.location}/data.yaml --cfg ./models/custom_yolov5s.yaml --weights '' --name yolov5s_results  --cache
# Out:
# /content/yolov5
# train: weights=, cfg=./models/custom_yolov5s.yaml, data=/content/yolov5/player-and-speed-detection-1/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=yolov5s_results, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 58 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-72-g064365d Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2023-03-27 17:37:36.575386: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-27 17:37:37.516532: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-27 17:37:37.516652: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-27 17:37:37.516671: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 18.0MB/s]
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     19904  models.common.BottleneckCSP             [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    161152  models.common.BottleneckCSP             [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    641792  models.common.BottleneckCSP             [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    378624  models.common.BottleneckCSP             [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     95104  models.common.BottleneckCSP             [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    313088  models.common.BottleneckCSP             [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1248768  models.common.BottleneckCSP             [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# custom_YOLOv5s summary: 233 layers, 7260488 parameters, 7260488 gradients
#
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 59 weight(decay=0.0), 70 weight(decay=0.0005), 62 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov5/player-and-speed-detection-1/train/labels... 216 images, 0 backgrounds, 0 corrupt: 100% 216/216 [00:00<00:00, 1796.06it/s]
# train: WARNING ⚠️ /content/yolov5/player-and-speed-detection-1/train/images/0bfacc_1_mp4-27_jpg.rf.45e280e780971d2e8a2a2ef0331896fb.jpg: 31 duplicate labels removed
# train: WARNING ⚠️ /content/yolov5/player-and-speed-detection-1/train/images/0bfacc_1_mp4-27_jpg.rf.467cf55a66a831efa177877ce0e139c3.jpg: 31 duplicate labels removed
# train: WARNING ⚠️ /content/yolov5/player-and-speed-detection-1/train/images/0bfacc_1_mp4-27_jpg.rf.5929594434ad2580f9f8552e57d1fd6d.jpg: 31 duplicate labels removed
# train: New cache created: /content/yolov5/player-and-speed-detection-1/train/labels.cache
# train: Caching images (0.1GB ram): 100% 216/216 [00:01<00:00, 187.66it/s]
# val: Scanning /content/yolov5/player-and-speed-detection-1/valid/labels... 21 images, 0 backgrounds, 0 corrupt: 100% 21/21 [00:00<00:00, 522.94it/s]
# val: WARNING ⚠️ /content/yolov5/player-and-speed-detection-1/valid/images/0bfacc_1_mp4-24_jpg.rf.6c2d97e7c1e9ed06d76e9f741b5df8f9.jpg: 15 duplicate labels removed
# val: New cache created: /content/yolov5/player-and-speed-detection-1/valid/labels.cache
# val: Caching images (0.0GB ram): 100% 21/21 [00:00<00:00, 35.71it/s]
#
# AutoAnchor: 2.31 anchors/target, 0.986 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/yolov5s_results/labels.jpg...
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to runs/train/yolov5s_results
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/99      1.76G     0.0888    0.04598     0.0254        331        416: 100% 14/14 [00:15<00:00,  1.07s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.85s/it]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/99      1.96G    0.09534     0.0482    0.02583        204        416: 100% 14/14 [00:04<00:00,  3.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.91it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/99      1.96G    0.08924    0.04852     0.0222        222        416: 100% 14/14 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.77it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/99      1.96G    0.08957    0.04808    0.02134        241        416: 100% 14/14 [00:04<00:00,  3.29it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.95it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/99      1.96G    0.08815     0.0482     0.0196        207        416: 100% 14/14 [00:03<00:00,  3.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.07it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/99      1.96G     0.0948    0.04826    0.02163        191        416: 100% 14/14 [00:03<00:00,  3.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.19it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/99      1.96G    0.08972    0.04818     0.0188        176        416: 100% 14/14 [00:05<00:00,  2.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.88it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/99      1.96G     0.0873    0.04792    0.01724        256        416: 100% 14/14 [00:03<00:00,  3.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.99it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/99      1.96G     0.0951    0.04717    0.01913        191        416: 100% 14/14 [00:04<00:00,  3.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.83it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/99      1.96G    0.08907    0.04778    0.01665        220        416: 100% 14/14 [00:03<00:00,  3.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.98it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/99      1.96G     0.1004    0.04692    0.01967        214        416: 100% 14/14 [00:03<00:00,  3.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.33it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/99      1.96G    0.08586    0.04793    0.01448        177        416: 100% 14/14 [00:05<00:00,  2.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.70it/s]
#                    all         21        466   7.22e-05   0.000803   3.78e-05   3.78e-06
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/99      1.96G    0.09195     0.0439    0.01466        175        416: 100% 14/14 [00:03<00:00,  3.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.40it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/99      1.96G     0.0882    0.04676    0.01373        247        416: 100% 14/14 [00:04<00:00,  3.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.13it/s]
#                    all         21        466          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/99      1.96G    0.08022    0.04677    0.01095        263        416: 100% 14/14 [00:04<00:00,  2.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.70it/s]
#                    all         21        466   0.000504    0.00482   0.000261   7.29e-05
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/99      1.96G     0.0859    0.04593    0.01177        186        416: 100% 14/14 [00:03<00:00,  3.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.85it/s]
#                    all         21        466    0.00138     0.0209    0.00081   0.000192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/99      1.96G    0.09158    0.04347    0.01298        261        416: 100% 14/14 [00:04<00:00,  3.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.11it/s]
#                    all         21        466    0.00201     0.0305    0.00278   0.000962
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/99      1.96G    0.08607    0.04428    0.01133        210        416: 100% 14/14 [00:04<00:00,  3.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.08it/s]
#                    all         21        466    0.00286     0.0434    0.00178   0.000458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/99      1.96G    0.09236    0.04722    0.01285        153        416: 100% 14/14 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.76it/s]
#                    all         21        466    0.00259     0.0394    0.00156   0.000393
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/99      1.96G    0.08629    0.04401    0.01005        317        416: 100% 14/14 [00:05<00:00,  2.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.23it/s]
#                    all         21        466    0.00392     0.0594    0.00248   0.000525
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/99      1.96G    0.08876    0.04433    0.01243        205        416: 100% 14/14 [00:03<00:00,  3.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.15it/s]
#                    all         21        466     0.0036     0.0546    0.00247   0.000568
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/99      1.96G    0.08827     0.0434   0.009702        231        416: 100% 14/14 [00:04<00:00,  2.89it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.22it/s]
#                    all         21        466    0.00333     0.0506    0.00271   0.000686
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/99      1.96G    0.08807    0.04251   0.009514        224        416: 100% 14/14 [00:03<00:00,  3.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.10it/s]
#                    all         21        466    0.00354     0.0538    0.00477    0.00167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/99      1.96G    0.08624     0.0445    0.01043        237        416: 100% 14/14 [00:03<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.80it/s]
#                    all         21        466    0.00376      0.057    0.00461    0.00103
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/99      1.96G    0.08334    0.04413    0.00958        210        416: 100% 14/14 [00:05<00:00,  2.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.92it/s]
#                    all         21        466    0.00344     0.0522    0.00309    0.00069
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/99      1.96G    0.08047      0.043   0.008749        190        416: 100% 14/14 [00:03<00:00,  3.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all         21        466    0.00328     0.0498    0.00238    0.00058
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/99      1.96G    0.08455    0.04384   0.009773        222        416: 100% 14/14 [00:04<00:00,  3.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.42it/s]
#                    all         21        466     0.0481     0.0458     0.0223    0.00473
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/99      1.96G    0.08306    0.04273   0.009756        281        416: 100% 14/14 [00:04<00:00,  3.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.14it/s]
#                    all         21        466      0.421     0.0514     0.0355    0.00799
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/99      1.96G    0.08282    0.04118       0.01        207        416: 100% 14/14 [00:03<00:00,  3.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.46it/s]
#                    all         21        466      0.443      0.105     0.0671     0.0162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/99      1.96G    0.07035     0.0441   0.008326        311        416: 100% 14/14 [00:05<00:00,  2.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.05it/s]
#                    all         21        466      0.432      0.144     0.0784     0.0176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       30/99      1.96G    0.06481    0.04283   0.007412        271        416: 100% 14/14 [00:03<00:00,  3.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.29it/s]
#                    all         21        466      0.454      0.138     0.0961     0.0242
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       31/99      1.96G    0.06917    0.04381   0.008592        208        416: 100% 14/14 [00:03<00:00,  3.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.37it/s]
#                    all         21        466      0.474       0.16      0.114      0.029
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       32/99      1.96G    0.06383    0.04315   0.007846        202        416: 100% 14/14 [00:04<00:00,  3.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.22it/s]
#                    all         21        466      0.404      0.138     0.0506    0.00969
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       33/99      1.96G    0.05904    0.04103   0.007532        269        416: 100% 14/14 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.06it/s]
#                    all         21        466      0.445      0.161      0.095     0.0253
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       34/99      1.96G    0.06616    0.04223   0.007628        248        416: 100% 14/14 [00:05<00:00,  2.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.89it/s]
#                    all         21        466      0.498      0.202      0.151     0.0461
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       35/99      1.96G    0.06301    0.04318   0.008046        274        416: 100% 14/14 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.62it/s]
#                    all         21        466      0.461      0.191      0.116     0.0334
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       36/99      1.96G    0.06239    0.04132    0.00841        218        416: 100% 14/14 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.99it/s]
#                    all         21        466      0.541      0.203      0.188     0.0604
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       37/99      1.96G    0.06227    0.04189   0.008244        198        416: 100% 14/14 [00:04<00:00,  2.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.96it/s]
#                    all         21        466      0.497      0.205      0.165     0.0514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       38/99      1.96G    0.05421    0.04184   0.008043        187        416: 100% 14/14 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.81it/s]
#                    all         21        466      0.515      0.194      0.177     0.0519
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       39/99      1.96G    0.05733    0.04135   0.006957        238        416: 100% 14/14 [00:05<00:00,  2.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.54it/s]
#                    all         21        466      0.527      0.197      0.187     0.0525
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       40/99      1.96G     0.0586    0.04053   0.007982        265        416: 100% 14/14 [00:03<00:00,  3.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.86it/s]
#                    all         21        466      0.501      0.206      0.171     0.0514
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       41/99      1.96G     0.0634    0.04121   0.008104        191        416: 100% 14/14 [00:04<00:00,  3.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.14it/s]
#                    all         21        466      0.857      0.185      0.179     0.0533
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       42/99      1.96G    0.05575    0.04062   0.007447        217        416: 100% 14/14 [00:05<00:00,  2.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.29it/s]
#                    all         21        466       0.52      0.199      0.176     0.0564
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       43/99      1.96G    0.06178    0.03947   0.008128        187        416: 100% 14/14 [00:03<00:00,  3.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.27it/s]
#                    all         21        466      0.893      0.216      0.214     0.0619
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       44/99      1.96G    0.05083    0.03982   0.007327        124        416: 100% 14/14 [00:04<00:00,  3.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.56it/s]
#                    all         21        466      0.845      0.185      0.183     0.0557
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       45/99      1.96G    0.05141    0.03966   0.007188        191        416: 100% 14/14 [00:04<00:00,  3.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.50it/s]
#                    all         21        466      0.902      0.229      0.238     0.0737
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       46/99      1.96G    0.05409    0.04013   0.007137        186        416: 100% 14/14 [00:03<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.35it/s]
#                    all         21        466       0.91      0.225      0.241     0.0843
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       47/99      1.96G    0.05341    0.03974   0.007511        159        416: 100% 14/14 [00:05<00:00,  2.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.14it/s]
#                    all         21        466      0.862       0.21      0.184     0.0544
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       48/99      1.96G    0.05567    0.04081   0.007495        322        416: 100% 14/14 [00:03<00:00,  3.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.29it/s]
#                    all         21        466      0.905      0.227       0.25     0.0847
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       49/99      1.96G    0.05011    0.03817   0.006986        241        416: 100% 14/14 [00:04<00:00,  3.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.61it/s]
#                    all         21        466      0.916      0.237       0.27     0.0925
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       50/99      1.96G    0.05261    0.04035   0.006681        328        416: 100% 14/14 [00:04<00:00,  3.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.22it/s]
#                    all         21        466      0.905      0.245      0.275     0.0964
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       51/99      1.96G    0.05368    0.04016   0.007435        264        416: 100% 14/14 [00:03<00:00,  3.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.24it/s]
#                    all         21        466      0.891      0.233      0.237     0.0711
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       52/99      1.96G    0.05862    0.03913   0.008168        189        416: 100% 14/14 [00:05<00:00,  2.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.81it/s]
#                    all         21        466      0.912      0.236      0.271      0.102
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       53/99      1.96G    0.05445    0.04038   0.006741        185        416: 100% 14/14 [00:03<00:00,  3.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.06it/s]
#                    all         21        466      0.908       0.25      0.281      0.108
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       54/99      1.96G    0.05568    0.03969    0.00769        196        416: 100% 14/14 [00:04<00:00,  3.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.49it/s]
#                    all         21        466      0.905      0.236      0.275     0.0994
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       55/99      1.96G    0.05655    0.03899    0.01206        295        416: 100% 14/14 [00:04<00:00,  2.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.40it/s]
#                    all         21        466      0.903      0.229      0.264     0.0952
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       56/99      1.96G    0.05085    0.03955   0.006651        252        416: 100% 14/14 [00:03<00:00,  3.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.36it/s]
#                    all         21        466      0.918      0.246      0.285     0.0969
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       57/99      1.96G    0.04871     0.0406    0.00656        253        416: 100% 14/14 [00:04<00:00,  3.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.51it/s]
#                    all         21        466      0.909      0.244       0.28      0.095
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       58/99      1.96G     0.0506    0.03884   0.006849        213        416: 100% 14/14 [00:03<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.68it/s]
#                    all         21        466      0.915      0.241      0.279      0.108
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       59/99      1.96G    0.05535    0.03947   0.007307        167        416: 100% 14/14 [00:04<00:00,  3.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.02it/s]
#                    all         21        466      0.729      0.292       0.29      0.116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       60/99      1.96G    0.06051    0.04032   0.006882        286        416: 100% 14/14 [00:05<00:00,  2.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.60it/s]
#                    all         21        466      0.764      0.296      0.301      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       61/99      1.96G    0.05687    0.03888   0.007334        241        416: 100% 14/14 [00:03<00:00,  3.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.95it/s]
#                    all         21        466      0.648      0.309      0.293      0.108
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       62/99      1.96G    0.04653    0.03883      0.006        271        416: 100% 14/14 [00:04<00:00,  2.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.18it/s]
#                    all         21        466      0.685      0.305      0.299      0.114
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       63/99      1.96G      0.052    0.04091   0.006775        242        416: 100% 14/14 [00:03<00:00,  3.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.40it/s]
#                    all         21        466      0.637      0.318      0.293     0.0991
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       64/99      1.96G    0.05254    0.03775   0.006396        231        416: 100% 14/14 [00:03<00:00,  3.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.17it/s]
#                    all         21        466      0.918      0.257      0.278      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       65/99      1.96G    0.05334    0.03923   0.007171        157        416: 100% 14/14 [00:05<00:00,  2.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.52it/s]
#                    all         21        466      0.924      0.255      0.277      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       66/99      1.96G    0.04403    0.03666    0.00617        199        416: 100% 14/14 [00:03<00:00,  4.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.88it/s]
#                    all         21        466      0.619      0.338      0.294      0.093
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       67/99      1.96G    0.04468    0.03841   0.007124        217        416: 100% 14/14 [00:03<00:00,  3.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.93it/s]
#                    all         21        466      0.662      0.341      0.299      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       68/99      1.96G    0.05156    0.03801   0.006929        194        416: 100% 14/14 [00:04<00:00,  3.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.18it/s]
#                    all         21        466      0.603      0.329      0.298      0.113
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       69/99      1.96G    0.04956     0.0381   0.006722        109        416: 100% 14/14 [00:03<00:00,  3.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.57it/s]
#                    all         21        466      0.641      0.321      0.299      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       70/99      1.96G     0.0484    0.03971   0.006455        230        416: 100% 14/14 [00:04<00:00,  3.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.56it/s]
#                    all         21        466      0.673      0.351      0.313      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       71/99      1.96G    0.05143    0.03755   0.007361        353        416: 100% 14/14 [00:03<00:00,  3.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.52it/s]
#                    all         21        466      0.638      0.313      0.291       0.11
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       72/99      1.96G    0.05129    0.03691    0.00779        147        416: 100% 14/14 [00:03<00:00,  4.02it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.28it/s]
#                    all         21        466      0.662      0.329      0.303       0.12
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       73/99      1.96G    0.04412     0.0383   0.006182        246        416: 100% 14/14 [00:05<00:00,  2.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.45it/s]
#                    all         21        466      0.662      0.351      0.309      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       74/99      1.96G    0.04359      0.038   0.005757        124        416: 100% 14/14 [00:03<00:00,  4.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.41it/s]
#                    all         21        466      0.669      0.338      0.304       0.12
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       75/99      1.96G    0.04327    0.03908   0.006871        309        416: 100% 14/14 [00:03<00:00,  4.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.86it/s]
#                    all         21        466       0.69      0.349       0.32      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       76/99      1.96G    0.04539    0.03855   0.006457        245        416: 100% 14/14 [00:04<00:00,  2.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.59it/s]
#                    all         21        466      0.662      0.359      0.312      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       77/99      1.96G    0.04547    0.03796   0.007581        358        416:  29% 4/14 [00:00<00:02,  4.45it/s]

# %%
# logs save in the folder "runs"
# %load_ext tensorboard
# %tensorboard --logdir runs

# %%
from utils.plots import plot_results  # plot results.txt as results.png
Image(filename='/content/yolov5/runs/train/yolov5s_results/results.png', width=1000)  # view results.png

# %%
# %ls runs/train/yolov5s_results/weights
